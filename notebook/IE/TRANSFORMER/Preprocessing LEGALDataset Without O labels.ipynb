# %%
import pandas as pd
import re

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/drive/MyDrive/Kuliah/Experiment 2/BERT/LEGALBERTNER-POS-PREV-NEXT-200.csv')
df
# Out:
#                                                     text  \
# 0      PUTUSAN . NOMOR : 1974 / Pid . Sus / 2012 / PN...
# 1      Pengadilan Negeri Jakarta Barat yang memeriksa...
# 2      AGNES TRI AHADI Als ANAS , lahir di Jakarta , ...
# 3      Terdakwa menolak didampingi oleh Penasehat Huk...
# 4                          Pengadilan Negeri tersebut ;
# ...                                                  ...
# 24510  - Bahwa yang menjadi tugas analisis dengan acc...
# 24511  Bahwa saksi kenal dengan terdakwa Mulyatno Wib...
# 24512  - Bahwa yang menjadi tugas Direktur Pemasaran ...
# 24513  - Bahwa Struktur pemberian kredit KMK Bank DKI...
# 24514     - Bahwa mekanisme perpanjangan dan penambahan
#
#                                                   labels
# 0      O O O O B_VERN I_VERN I_VERN I_VERN I_VERN I_V...
# 1      O O O O O O O O O O O O O O O O O O O O O O O ...
# 2      B_DEFN I_DEFN I_DEFN I_DEFN I_DEFN I_DEFN O O ...
# ...

# %%
labels = df['labels']

# %%
for i, label in labels.iteritems():
  if bool(re.search(r'\b(?!O\b)\w+\b', label)) != True:
    df = df.drop(i)

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                                    text  \
# 0     PUTUSAN . NOMOR : 1974 / Pid . Sus / 2012 / PN...
# 1     AGNES TRI AHADI Als ANAS , lahir di Jakarta , ...
# 2     MENUNTUT : 1 Menyatakan terdakwa AGNES TRI AHA...
# 3     2 Menjatuhkan pidana terhadap terdakwa DERRY S...
# 4     Menimbang , bahwa terdakwa didakwa dengan sura...
# ...                                                 ...
# 7949  - Bahwa yang ditunjuk untuk melakukan site vis...
# 7950  Bahwa pada bagian III . Isi . MAK . No . 183 /...
# 7951  9 . Bahwa atas kredit PT Likotama Harum telah ...
# 7952  Bahwa sepengetahuan saksi , pemberian kredit k...
# 7953  Bahwa saksi kenal dengan terdakwa Mulyatno Wib...
#
#                                                  labels
# 0     O O O O B_VERN I_VERN I_VERN I_VERN I_VERN I_V...
# 1     B_DEFN I_DEFN I_DEFN I_DEFN I_DEFN I_DEFN O O ...
# 2     O O O O O B_DEFN I_DEFN I_DEFN I_DEFN I_DEFN O...
# 3     O O O O O B_DEFN I_DEFN I_DEFN I_DEFN O O O O ...
# ...

# %%
df.to_csv('LegalNER NEW.csv', index=False)
